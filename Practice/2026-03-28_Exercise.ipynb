# %%
class ShoppingCart:
    def __init__(self):
        self.items = []

    def addItem(self, item, price):
        self.items.append((item, price))

    def removeItem(self, item, price):
        for product in self.items:
            if product[0] == item and product[1] == price:
                self.items.remove(product)
                print(f"Product {product} removed.")
                return
            print("Book not found!")

    def showShoppingCart(self):
        print("Items in Shopping Cart:")
        for product in self.items:
            print(product)

cart1 = ShoppingCart()
cart1.addItem("banana", 3000)
cart1.addItem("apple", 5000)
cart2 = ShoppingCart()
cart2.addItem("milk", 3000)
cart1.showShoppingCart()
print()
cart2.showShoppingCart()

cart1.removeItem("banana", 3000)
print()
cart1.showShoppingCart()

cart2.removeItem("milk", 3000)
print()
cart2.showShoppingCart()
# Out:
# Items in Shopping Cart:
# ('banana', 3000)
# ('apple', 5000)
#
# Items in Shopping Cart:
# ('milk', 3000)
# Product ('banana', 3000) removed.
#
# Items in Shopping Cart:
# ('apple', 5000)
# Product ('milk', 3000) removed.
#
# Items in Shopping Cart:

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 0


    # def __str__(self):
    #     temp_node = self.head
    #     result = ''
    #     while temp_node is not None:
    #         result += str(temp_node.value)
    #         if temp_node.next is not None:
    #             result += " -> "
    #         temp_node = temp_node.next
    #     return result

    
    def __str__(self):
        values = []
        temp_node = self.head
        while temp_node:
            values.append(str(temp_node.value))
            temp_node = temp_node.next
        return " -> ".join(values)
    
    def append(self, value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node
            self.length += 1

    def prepend(self, value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            new_node.next = self.head
            self.head = new_node

    def insert(self, index, value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            temp_node = self.head
            for _ in range(index - 1):
                temp_node = temp_node.next
            new_node.next = temp_node.next
            temp_node.next = new_node
        self.length += 1

    def traverse(self):
        temp_node = self.head
        while temp_node is not None:
            print(temp_node.value)
            temp_node = temp_node.next

    def search(self, target):
        index = 0
        temp_node = self.head
        while temp_node is not None:
            if temp_node.value == target:
                return index
            temp_node = temp_node.next
            index += 1
        return -1

    def pop(self):
        popped_node = self.head
        if self.length == 1:
            self.head = None
            self.tail = None
        else:
            temp = self.head
            while temp.next is not self.tail:
                temp = temp.next
            self.tail = temp
            temp.next = None
        self.length -= 1
        return popped_node
    
    def pop_first(self):
        popped_node = self.head
        if self.length == 1:
            self.head = None
            self.tail = None
        else:
            self.head = self.head.next
            popped_node.next = None
        self.length -= 1
    
    def delete_all(self):
        self.head = None
        self.tail = None
        self.length = 0


new_linked_list = LinkedList()
new_linked_list.append(10)
new_linked_list.append(20)
new_linked_list.append(30)
new_linked_list.prepend(100)
new_linked_list.insert(2, 70)
print(new_linked_list)
new_linked_list.traverse()
print(new_linked_list.search(30))
print(new_linked_list.search(90))
print(new_linked_list.pop())
print(new_linked_list)

print(new_linked_list.pop_first())
print(new_linked_list)

print(new_linked_list.delete_all())
print(new_linked_list)
# Out:
# 100 -> 10 -> 70 -> 20 -> 30
# 100
# 10
# 70
# 20
# 30
# 4
# -1
# <__main__.Node object at 0x0000029860452FD0>
# 100 -> 10 -> 70 -> 20
# None
# 10 -> 70 -> 20
# None
